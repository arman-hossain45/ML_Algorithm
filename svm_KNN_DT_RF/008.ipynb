# %%
import seaborn as sns

df_O = sns.load_dataset("penguins")
df_O.head(10)

# %%
df_O.shape

# %%
df_O.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_O.dropna()
#
# NameError: name 'df_O' is not defined

# %%
df_r=pd.read_csv("penguins_variation.csv")
df_r.head(10)
df_r.nunique()

# %%
df_r.shape
