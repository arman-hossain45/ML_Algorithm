# %%
print("Principal component analysis (PCA)")
# Out:
# Principal component analysis (PCA)

# %% [markdown]
# amra noisy data set a  pca apply korle better accuracy pabo .kintu noise less
#
# data set a pca apply korle accuracy kombe karon sobgula feature e overall
#
# important here .
#
# we use or apply pca unclean and  large feature data set

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
#noise less data set 
data=load_wine()
x=pd.DataFrame(data.data,columns=data.feature_names)
y=pd.Series(data.target,name='class')

# %%
print("X shape :",x.shape)

print("y shape :",y.shape)
# Out:
# X shape : (178, 13)
# y shape : (178,)

# %%
x.head(5)
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %%
x.describe().T

#here std is high so we apply standard scaler to the data set
# Out:
#                               count        mean  ...       75%      max
# alcohol                       178.0   13.000618  ...   13.6775    14.83
# malic_acid                    178.0    2.336348  ...    3.0825     5.80
# ash                           178.0    2.366517  ...    2.5575     3.23
# alcalinity_of_ash             178.0   19.494944  ...   21.5000    30.00
# magnesium                     178.0   99.741573  ...  107.0000   162.00
# total_phenols                 178.0    2.295112  ...    2.8000     3.88
# flavanoids                    178.0    2.029270  ...    2.8750     5.08
# nonflavanoid_phenols          178.0    0.361854  ...    0.4375     0.66
# proanthocyanins               178.0    1.590899  ...    1.9500     3.58
# color_intensity               178.0    5.058090  ...    6.2000    13.00
# hue                           178.0    0.957449  ...    1.1200     1.71
# od280/od315_of_diluted_wines  178.0    2.611685  ...    3.1700     4.00
# proline                       178.0  746.893258  ...  985.0000  1680.00
#
# [13 rows x 8 columns]

# %%
#apply standard scaller
scaler=StandardScaler()

x_scale=scaler.fit_transform(x)

x_scale[:5]
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, -0.2687382 ,  0.08835836,
#          0.80899739,  1.21553297, -0.49840699,  2.13596773,  0.26901965,
#          0.31830389,  0.78858745,  1.39514818],
#        [ 1.69154964, -0.34681064,  0.4879264 , -0.80925118,  0.93091845,
#          2.49144552,  1.46652465, -0.98187536,  1.03215473,  1.18606801,
#         -0.42754369,  1.18407144,  2.33457383],
#        [ 0.29570023,  0.22769377,  1.84040254,  0.45194578,  1.28198515,
#          0.80899739,  0.66335127,  0.22679555,  0.40140444, -0.31927553,
#          0.36217728,  0.44960118, -0.03787401]])

# %% [markdown]
# Fit PCa (no component limit yet )

# %%
pca_full=PCA()#here we no declaire how many pca will create so its create totall
#13 PCA overAll 
x_pca_full=pca_full.fit_transform(x_scale)#eighen_value and eigen_vector create kore 
#fit kore overall model ta PCA ar perspective ar sathe 

explained=pca_full.explained_variance_ratio_
#ata protteckta  component a koto tuku value capture korte partese ta amader bole dey

cumula_explained=np.cumsum(explained)

explained[:13]
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823, 0.04238679, 0.02680749, 0.02222153, 0.01930019,
#        0.01736836, 0.01298233, 0.00795215])

# %% [markdown]
# np.cumsum Library diye amra dekte pari kon  feature gula importance and one by one sum so we can for that reason we can understand how many feature are we should take and its cover how many percent we see the output that first 3 feature cover 0.66 percent of the data set

# %%
cumula_explained[:13]
# Out:
# array([0.36198848, 0.55406338, 0.66529969, 0.73598999, 0.80162293,
#        0.85098116, 0.89336795, 0.92017544, 0.94239698, 0.96169717,
#        0.97906553, 0.99204785, 1.        ])

# %%
#we draw a plot over all feature importances

plt.figure()
plt.plot(cumula_explained,marker="o")
plt.xlabel("Number of components ")
plt.ylabel("Cumulative Explained Variance ")
plt.grid()
plt.show()

# %%
#selection of k 90 and k 95
def components_for_threshold(cum_variance,threashold):
    return int(np.argmax(cum_variance>=threashold)+1)

k90=components_for_threshold(cumula_explained,0.90)
print(k90)
# Out:
# 8

# %%
k95=components_for_threshold(cumula_explained,0.95)
print(k95)
# Out:
# 10

# %%
k97=components_for_threshold(cumula_explained,0.97)
print(k97)
# Out:
# 11

# %%
k=k95

pca=PCA(n_components=k)
x_pca=pca.fit_transform(x_scale)

x_pca.shape
# here is new feature
# Out:
# (178, 10)

# %%
loadings=pd.DataFrame(
    pca.components_.T,
    index=x.columns,
    columns=[f"Pc{i+1}" for i in range(k)]
)

loadings.head(13)

#pca a create korar jonno kon columns koto tuku obodhan rakse ta amra dektesi
# Out:
#                                    Pc1       Pc2  ...       Pc9      Pc10
# alcohol                       0.144329  0.483652  ... -0.508619  0.211605
# malic_acid                   -0.245188  0.224931  ...  0.075283 -0.309080
# ash                          -0.002051  0.316069  ...  0.307694 -0.027125
# alcalinity_of_ash            -0.239320 -0.010591  ... -0.200449  0.052799
# magnesium                     0.141992  0.299634  ... -0.271403  0.067870
# total_phenols                 0.394661  0.065040  ... -0.286035 -0.320131
# flavanoids                    0.422934 -0.003360  ... -0.049578 -0.163151
# nonflavanoid_phenols         -0.298533  0.028779  ... -0.195501  0.215535
# proanthocyanins               0.313429  0.039302  ...  0.209145  0.134184
# color_intensity              -0.088617  0.529996  ... -0.056218 -0.290775
# hue                           0.296715 -0.279235  ... -0.085828 -0.522399
# od280/od315_of_diluted_wines  0.376167 -0.164496  ... -0.137227  0.523706
# proline                       0.286752  0.364903  ...  0.575786  0.162116
#
# [13 rows x 10 columns]

# %% [markdown]
# which orginal feature has biggest absolate weight ?  for PCA1 or Any PCA
#
#  aikhan a amra deklam muloto je new feature gula create hoise tader
#
# TAR jonno newly feature a kar contribution koto tuku
#
#  AMRA  duita PCA ar jonno deklam aikhan a

# %%
def top_loadings_for_pca(loadings_df,pc_name,top_n=5):
    s=loadings_df[pc_name].abs().sort_values(ascending=False).head(top_n)
    return pd.DataFrame({"feature":s.index,"abs_loadin":s.values})

top_pc1=top_loadings_for_pca(loadings,"Pc1",top_n=5)
top_pc1
# Out:
#                         feature  abs_loadin
# 0                    flavanoids    0.422934
# 1                 total_phenols    0.394661
# 2  od280/od315_of_diluted_wines    0.376167
# 3               proanthocyanins    0.313429
# 4          nonflavanoid_phenols    0.298533

# %%
top_pc2=top_loadings_for_pca(loadings,"Pc2",top_n=5)
top_pc2
# Out:
#            feature  abs_loadin
# 0  color_intensity    0.529996
# 1          alcohol    0.483652
# 2          proline    0.364903
# 3              ash    0.316069
# 4        magnesium    0.299634

# %%
pca2 = PCA(n_components=2)
X_2d = pca2.fit_transform(x_scale)

plt.figure()
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y, cmap="viridis")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid()
plt.colorbar(scatter, label="Class")
plt.show()
